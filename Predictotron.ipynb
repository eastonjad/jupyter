# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql://predictotron:password@localhost/predictotron')

# %%
# %load_ext sql

# %%
# %sql mysql://predictotron:D0dg3raM@localhost/predictotron

# %%
# %sql select * from integrity_tracker_proclamation
# Out:
#  * mysql://predictotron:***@localhost/predictotron
# 5 rows affected.
# [(1, "COVID-19 Will Disappear 'Like a Miracle'", 'Trump claims that the COVID-19 virus will simply go away by itself', 0, datetime.datetime(2020, 2, 27, 0, 0), datetime.datetime(2020, 8, 31, 0, 0), 'N', 1, 0, 'O', datetime.datetime(2020, 8, 18, 2, 11, 56, 336376), 1, 1, 0, 2, 2),
#  (2, 'Alberta will have $714 million surplus by 2023', 'Jason Kenney and the UCP promise budget surplus and reduced debt by 2023', 1, datetime.datetime(2019, 3, 30, 0, 0), datetime.datetime(2023, 12, 31, 0, 0), 'N', 1, 0, 'O', datetime.datetime(2020, 8, 20, 2, 23, 56, 517034), 1, 2, 0, 2, 2),
#  (3, 'Test 1', 'THis is a test proclamation submission//..,', 0, datetime.datetime(2020, 10, 11, 0, 0), datetime.datetime(2020, 10, 13, 0, 0), 'N', 0, 0, 'O', datetime.datetime(2020, 10, 11, 18, 1, 28, 640188), 1, 1, 0, 2, 2),
# ...

# %%
vote_score = %sql select vote_score from integrity_tracker_proclamation where id = 1
print(vote_score)
# Out:
#  * mysql://predictotron:***@localhost/predictotron
# 1 rows affected.
# +------------+
# | vote_score |
# +------------+
# |     2      |
# +------------+

# %%
print(vote_score[0][0])
# Out:
# 2

# %%
result = %sql select * from integrity_tracker_proclamation
df = result.DataFrame()
# Out:
#  * mysql://predictotron:***@localhost/predictotron
# 5 rows affected.

# %%
df
# Out:
#    id                                              title  \
# 0   1           COVID-19 Will Disappear 'Like a Miracle'
# 1   2     Alberta will have $714 million surplus by 2023
# 2   3                                             Test 1
# 3   4  All Canadian Boil-Water Advisories Will Be Lif...
# 4   9  We will build a wall along the Southern Border...
#
#                                          description  is_promise  \
# 0  Trump claims that the COVID-19 virus will simp...           0
# 1  Jason Kenney and the UCP promise budget surplu...           1
# 2        THis is a test proclamation submission//..,           0
# 3  Trudeau promises that all Canadian Boil-Water ...           1
# 4  Trump promises to build a wall along the borde...           1
#
#   proclamation_date   end_date status  is_public  revision_no revision_code  \
# 0        2020-02-27 2020-08-31      N          1            0             O
# ...

# %%
import pandas as pd

# %%
data = pd.read_sql_table('integrity_tracker_proclamation', engine)

# %%
data
# Out:
#    id                                              title  \
# 0   1           COVID-19 Will Disappear 'Like a Miracle'
# 1   2     Alberta will have $714 million surplus by 2023
# 2   3                                             Test 1
# 3   4  All Canadian Boil-Water Advisories Will Be Lif...
# 4   9  We will build a wall along the Southern Border...
#
#                                          description  is_promise  \
# 0  Trump claims that the COVID-19 virus will simp...           0
# 1  Jason Kenney and the UCP promise budget surplu...           1
# 2        THis is a test proclamation submission//..,           0
# 3  Trudeau promises that all Canadian Boil-Water ...           1
# 4  Trump promises to build a wall along the borde...           1
#
#   proclamation_date   end_date status  is_public  revision_no revision_code  \
# 0        2020-02-27 2020-08-31      N          1            0             O
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5 non-null      int64
#  1   title              5 non-null      object
#  2   description        5 non-null      object
#  3   is_promise         5 non-null      int64
#  4   proclamation_date  5 non-null      datetime64[ns]
#  5   end_date           5 non-null      datetime64[ns]
#  6   status             5 non-null      object
#  7   is_public          5 non-null      int64
#  8   revision_no        5 non-null      int64
#  9   revision_code      5 non-null      object
#  10  created_date       5 non-null      datetime64[ns]
#  11  created_by_id      5 non-null      int64
#  12  proclaimer_id      5 non-null      int64
#  13  num_vote_down      5 non-null      int64
#  14  num_vote_up        5 non-null      int64
# ...

# %%
data.describe()
# Out:
#              id  is_promise  is_public  revision_no  created_by_id  \
# count  5.000000    5.000000   5.000000          5.0       5.000000
# mean   3.800000    0.600000   0.800000          0.0       1.200000
# std    3.114482    0.547723   0.447214          0.0       0.447214
# min    1.000000    0.000000   0.000000          0.0       1.000000
# 25%    2.000000    0.000000   1.000000          0.0       1.000000
# 50%    3.000000    1.000000   1.000000          0.0       1.000000
# 75%    4.000000    1.000000   1.000000          0.0       1.000000
# max    9.000000    1.000000   1.000000          0.0       2.000000
#
#        proclaimer_id  num_vote_down  num_vote_up  vote_score
# count       5.000000            5.0     5.000000    5.000000
# mean        1.600000            0.0     1.400000    1.400000
# std         0.894427            0.0     0.894427    0.894427
# min         1.000000            0.0     0.000000    0.000000
# ...

# %%
import numpy as np

# %%
data.describe(include=np.object)
# Out:
#                                                     title  \
# count                                                   5
# unique                                                  5
# top     All Canadian Boil-Water Advisories Will Be Lif...
# freq                                                    1
#
#                                               description status revision_code
# count                                                   5      5             5
# unique                                                  5      1             1
# top     Trump promises to build a wall along the borde...      N             O
# freq                                                    1      5             5
